# %%
shieldDF = top_df.drop(columns=['rank'])
shieldDF.loc[:,'low_shield_count'] = (shieldDF['stand_heal_count']) + (shieldDF['crit_heal_count']) + (shieldDF['draw_count'])
foo = shieldDF.drop(columns=['crit_heal_count', 'date']).groupby('boss').describe()
foo.sort_values(('wins', 'mean')).loc[:, (slice(None), ['count', 'mean', 'std'])]

# %%
shieldDF = full_df.drop(columns=['rank'])
shieldDF.loc[:,'low_shield_count'] = (shieldDF['stand_heal_count']) + (shieldDF['crit_heal_count']) + (shieldDF['draw_count'])
foo = shieldDF.drop(columns=['crit_heal_count', 'date']).groupby('boss').describe().loc[:, (slice(None), ['count', 'mean', 'std'])]
foo.sort_values(('wins', 'mean'))
# foo.sort_values(['count'])
# Out:
#                                                      wins                      \
#                                                     count      mean       std
# boss
# Soul Awakening Guard, Leuhan                          2.0  0.000000  0.000000
# Lyrical ShootingStarS ☆ Special Issue                 1.0  0.000000       NaN
# Lone Warrior, Superbia (Deathdrives)                  1.0  0.000000       NaN
# Judgment Blades Equip, Ars Vairina                    1.0  0.000000       NaN
# Innocent Cry, Tomori Takamatsu                        2.0  0.000000  0.000000
# Bombing Juggler                                       1.0  0.000000       NaN
# Spirit of Sword, Yoh Asakura                          1.0  0.000000       NaN
# Mutsunokami Yoshiyuki Kiwame Sentou                   1.0  0.000000       NaN
# Marine General of the Great Sea, Cristianos           1.0  0.000000       NaN
# Sword Saint Knight Dragon, Gramgrace                  1.0  0.000000       NaN
# ...
