# %% [markdown]
# test

# %%
strs = [
    '1st'
    ,'10th'
]
for st in strs:
    print(st[:-2])
# Out:
# 1
# 10

# %%
tests = [
    'idSoAndSo : Test Name',
    'testID : Test Name'
]
for test in tests:
    foo = test.split(' : ')[1]
    print(foo)
# Out:
# Test Name
# Test Name

# %%
test = {}
print(test==True)
# Out:
# False

# %%
import requests 
BASE_URL = 'https://en.cf-vanguard.com/cardlist/?cardno='
from bs4 import BeautifulSoup as Soup

TEST_EXT = 'DZ-SS08/032EN'
soup = Soup(requests.get(BASE_URL+TEST_EXT).text, 'html.parser')
data_element = soup.find(attrs={'class':'data'})

# %%
for child in data_element.findChildren(recursive=False):
    print(child)
    print('~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# <div class="name">
# <span class="face">Blaze War Monk, Sougyou</span>
# <span class="ruby"></span>
# </div>
# ~~~~~~~~~~~~~~~~~~~~~~~
# <hr/>
# ~~~~~~~~~~~~~~~~~~~~~~~
# <div class="text-list">
# <div class="type">Trigger Unit</div>
# <div class="nation">Dragon Empire</div>
# <div class="race">Human</div>
# <div class="grade">Grade 0</div>
# <div class="power">Power 5000</div>
# <div class="critical">Critical 1</div>
# <div class="shield">Shield 15000</div>
# <div class="skill">Boost</div>
# <div class="gift">Critical Trigger +10000</div>
# </div>
# ~~~~~~~~~~~~~~~~~~~~~~~
# <div class="effect"></div>
# ~~~~~~~~~~~~~~~~~~~~~~~
# <div class="flavor">This greatsword cloaked in flames,
# cannot be seen through by mere amateurs!</div>
# ~~~~~~~~~~~~~~~~~~~~~~~
# <div class="text-list">
# <div class="regulation">
# Standard</div>
# <div class="number">DZ-SS08/032EN</div>
# <div class="rarity">C</div>
# <div class="illstrator">illust/モレシャン</div>
# </div>
# ~~~~~~~~~~~~~~~~~~~~~~~
# C:\Users\Mimi\AppData\Local\Temp\ipykernel_7520\547893063.py:1: DeprecationWarning: Call to deprecated method findChildren. (Replaced by find_all) -- Deprecated since version 3.0.0.
#   for child in data_element.findChildren(recursive=False):
