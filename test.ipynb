# %% [markdown]
# test

# %%
strs = [
    '1st'
    ,'10th'
]
for st in strs:
    print(st[:-2])
# Out:
# 1
# 10

# %%
tests = [
    'idSoAndSo : Test Name',
    'testID : Test Name'
]
for test in tests:
    foo = test.split(' : ')[1]
    print(foo)
# Out:
# Test Name
# Test Name

# %%
test = {}
print(test==True)
# Out:
# False

# %%
import requests 
BASE_URL = 'https://en.cf-vanguard.com/cardlist/?cardno='
from bs4 import BeautifulSoup as Soup

TEST_EXT = 'DZ-SS08/032EN'
soup = Soup(requests.get(BASE_URL+TEST_EXT).text, 'html.parser')
data_element = soup.find(attrs={'class':'data'})

# %%
# for child in data_element.findChildren(recursive=False):
#     print(child)
#     print('~~~~~~~~~~~~~~~~~~~~~~~')

#todo ensure correct line breaks
b = data_element.find(attrs={'class':'effect'}).text
c = data_element.find(attrs={'class':'flavor'}).text
a, d = data_element.find_all(recursive=False, attrs={'class':'text-list'})
a = a.text.strip().split('\n')
d = d.text.strip().split('\n')
print(a,'\n',b,'\n',c,'\n',d)
# Out:
# ['Trigger Unit', 'Dragon Empire', 'Human', 'Grade 0', 'Power 5000', 'Critical 1', 'Shield 15000', 'Boost', 'Critical Trigger +10000']
#
#  This greatsword cloaked in flames,
# cannot be seen through by mere amateurs!
#  ['Standard', 'DZ-SS08/032EN', 'C', 'illust/モレシャン']

# %%
a.text.strip().split('\n')
# Out:
# ['Trigger Unit',
#  'Dragon Empire',
#  'Human',
#  'Grade 0',
#  'Power 5000',
#  'Critical 1',
#  'Shield 15000',
#  'Boost',
#  'Critical Trigger +10000']

# %%
b.text.strip().split('\n')
# Out:
# ['Standard', 'DZ-SS08/032EN', 'C', 'illust/モレシャン']

# %%
str.strip
